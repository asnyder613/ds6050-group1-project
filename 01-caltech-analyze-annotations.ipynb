# %% [markdown]
# # ECP Annotation Analysis
# **Purpose: Analyze Distributions of Annotations**</br>
# **Final Project**</br>
# **Group 1**</br>
# **DS6050 Deep Learning**</br>
# **Fall 2023**</br>

# %%
from pylabel import importer
import yaml
# Out:
# /home/ybt7qf/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
path_to_annotations = "/scratch/ybt7qf/ds6050-group1-project/datasets/caltechpedestriandataset/labels/train/"
path_to_images = "/scratch/ybt7qf/ds6050-group1-project/datasets/caltechpedestriandataset/images/train/"
path_to_yolo_yaml = "/scratch/ybt7qf/ds6050-group1-project/datasets/caltechpedestriandataset.yaml"
name = "caltechpedestriandataset"

# %%
with open(path_to_yolo_yaml, 'r') as file:
    content = file.read()
data = yaml.load(content, Loader=yaml.FullLoader)

# %%
classes = data['names']
dataset = importer.ImportYoloV5(
    path=path_to_annotations,
    path_to_images=path_to_images,
    cat_names=classes,
    img_ext="png",
    name=name
)
# Out:
# Importing YOLO files...: 100%|██████████| 10000/10000 [01:16<00:00, 130.27it/s]

# %%
dataset.df.head()
# Out:
#                                            img_folder         img_filename  \
# id
# 0   /scratch/ybt7qf/ds6050-group1-project/datasets...  set00_V013_0654.png
# 1   /scratch/ybt7qf/ds6050-group1-project/datasets...  set00_V002_0331.png
# 2   /scratch/ybt7qf/ds6050-group1-project/datasets...  set00_V012_0488.png
# 3   /scratch/ybt7qf/ds6050-group1-project/datasets...  set00_V001_0922.png
# 4   /scratch/ybt7qf/ds6050-group1-project/datasets...  set00_V009_0254.png
#
#    img_path  img_id  img_width  img_height  img_depth ann_segmented  \
# id
# 0                 0        640         480          3
# 1                 1        640         480          3
# 2                 2        640         480          3
# 3                 3        640         480          3
# 4                 4        640         480          3
#
#     ann_bbox_xmin  ann_bbox_ymin  ...  ann_iscrowd  ann_keypoints  ann_pose  \
# id                                ...
# 0      579.226361     143.292949  ...
# 1      519.792548     116.814591  ...
# 2      405.267189     113.040410  ...
# 3      431.645973     117.260229  ...
# 4       12.961580     152.120119  ...
#
#     ann_truncated  ann_difficult cat_id cat_name cat_supercategory split  \
# id
# 0                                     0   person
# 1                                     0   person
# 2                                     0   person
# 3                                     0   person
# 4                                     0   person
#
#    annotated
# id
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 26 columns]

# %%
print(f"Number of images: {dataset.analyze.num_images}")
print(f"Number of classes: {dataset.analyze.num_classes}")
print(f"Classes: {dataset.analyze.classes}")
print(f"Class counts:\n{dataset.analyze.class_counts}")
# Out:
# Number of images: 10000
# Number of classes: 1
# Classes: ['person']
# Class counts:
# cat_name
# person    19365
# Name: count, dtype: int64
